# %% [markdown]
# # 본인이 사용하는 IDE 스크린샷 이미지

# %% [markdown]
# ![%EB%82%B4%EA%B0%80%20%EC%82%AC%EC%9A%A9%ED%95%98%EB%8A%94%20iDE%20%EC%BA%A1%EC%B2%98.PNG](attachment:%EB%82%B4%EA%B0%80%20%EC%82%AC%EC%9A%A9%ED%95%98%EB%8A%94%20iDE%20%EC%BA%A1%EC%B2%98.PNG)

# %%
# 제가 사용하는 IDE는 repl.it입니다.

# %% [markdown]
# # Work directory를 Github repository에 연결한 스크린샷

# %% [markdown]
# ![work%20directory%EB%A5%BC%20git-hub%EC%97%90%20%EC%97%B0%EB%8F%99.PNG](attachment:work%20directory%EB%A5%BC%20git-hub%EC%97%90%20%EC%97%B0%EB%8F%99.PNG)

# %%
# 저는 왕복 4~5시간 거리를 통학하고, 노트북이 아닌 갤럭시 tap을 들고 다니기 때문에
# pc와 mobile에서 모두 edit가능하고 git-hup에 upload나 push-pull이 모두 가능한 repl.it을 선택했습니다
# 왼쪽은 제 git-hub repository이며, 오른쪽은 제가 사용하는 IDE의 wrok directory와 
# git hub가 연동되어서 실시간으로 업로드 되는 사진입니다.

# %% [markdown]
# # 선형 리스트 생성 프로그램 작성 코드

# %%
#전역 변수
unit = []
select = -1

#추가 함수 (1번 선택 시 호출할 함수)
def add_data(data):
  unit.append(None)
  kLen = len(unit)
  unit[kLen-1] = data

#제거 함수 (2번 선택 시호출할 함수)
def delete_data(position):
  if position <= 0 or position > len(unit):
    print("삭제할 데이터가 존재하지 않습니다.")
    return
    
  del(unit[position-1]) #조건, 리스트의 특정 순서의 값을 삭제해야 하므로 del(unit[특정순서])를 사용
  print(unit)           #ex)  2번 순서의 값을 delete ---> del(unit[2-1])


#튜플 정렬하기 위한 sort_key정의
def sort_value(x):
    return x[1]


#메인 코드 부분 
while(select != 3):
  select = int(input("선택하세요(1: 추가, 2: 삭제, 3: 종료)--> "))

  if(select == 1):
    name = input("유닛 이름을 입력하세요 --> ") 
    hp = int(input("유닛의 체력을 입력하세요 --> "))
    data = (name, hp) #조건, 데이터를 tuple형태로 넣어준다.
    add_data(data)
    unit.sort(key=sort_value, reverse = True) #조건, 숫자가 내림차순 순서대로 정렬을하기 위해서 ,reverse = True라는 구문을 추가해준다
    print(unit)
    
  elif(select == 2):
    delete_index_number = int(input("몇번 자리의 unit를 삭제하시겠습니까?--> "))
    delete_data(delete_index_number)
    
  elif(select == 3):
    exit
    
  else:
    print("1~3 중 하나를 입력하세요.")
    continue
# Out:
# 선택하세요(1: 추가, 2: 삭제, 3: 종료)--> 1
# 유닛 이름을 입력하세요 --> 마린
# 유닛의 체력을 입력하세요 --> 10
# [('마린', 10)]
# 선택하세요(1: 추가, 2: 삭제, 3: 종료)--> 1
# 유닛 이름을 입력하세요 --> 탱크
# 유닛의 체력을 입력하세요 --> 40
# [('탱크', 40), ('마린', 10)]
# 선택하세요(1: 추가, 2: 삭제, 3: 종료)--> 1
# 유닛 이름을 입력하세요 --> 레이스
# 유닛의 체력을 입력하세요 --> 25
# [('탱크', 40), ('레이스', 25), ('마린', 10)]
# 선택하세요(1: 추가, 2: 삭제, 3: 종료)--> 2
# 몇번 자리의 unit를 삭제하시겠습니까?--> 2
# [('탱크', 40), ('마린', 10)]
# 선택하세요(1: 추가, 2: 삭제, 3: 종료)--> 2
# 몇번 자리의 unit를 삭제하시겠습니까?--> 2
# [('탱크', 40)]
# 선택하세요(1: 추가, 2: 삭제, 3: 종료)--> 2
# 몇번 자리의 unit를 삭제하시겠습니까?--> 2
# 삭제할 데이터가 존재하지 않습니다.
# 선택하세요(1: 추가, 2: 삭제, 3: 종료)--> 3

# %%
# 데이터를 튜플 형태로 받기 위해 data = (name, hp)로 문장을 작성했습니다.
# 데이터의 순서는 숫자 순서대로 배열하기 위해 오름차순인 sort()에 reverse = True를 추가했습니다
# 새로운 데이터를 배열에 맞춰 add 하기 위해 .append()를 사용했습니다.
# 선형 리스트의 특정 순서의 값을 delete하기 위해 remove()가 아닌 del + index조합을 사용했습니다.

# %% [markdown]
# # 과제 후기

# %% [markdown]
# 웹 백엔드 개발자가 되는 게 목표인 저에게는 너무 좋은 경험이였던 것 같습니다.
# vscode나 replit이외에 이미지나 동영상이 첨부되면서 한 줄 한줄 실행결과를 보며 코딩할 수 있는 jupyter notebook이라는 새로운 개발환경도 알게되고, git-hub에 처음 repository도 처음 만들게 되었습니다.
#
# 다른 코딩 강의에서는 기본 문법인 if-else문까지 배우고 중간고사를 보고, 배열과 class까지 배운 후 기말고사를 보고 조금 형식적으로만 코딩을 배웠는데 처음으로 실무에서 쓰이는 것들을 접하게 된 것 같습니다.
#
# 특히, 과제에 올라온 실행결과창과 100% 유사하게 만드려고 각 method에 대한 기능을 구글링이나 다양한 플랫폼 검색을 통해서 계속 보다보니까 개인적으로 실력이 많이 향상되었다는 느낌도 받았고, 나중에 실제로 취업해서 customer의 요구를 최대한 반영할 수 있겠다는 자신감도 생긴 것 같습니다.
#
# 비록 지금은 input을 2줄로 받아서 결과창과 아예 똑같게는 만들지 못했지만 앞으로는 더 열심히해서 유사하게 만들어보고 싶습니다.
# +a 수업도 너무 재밌어요 감사합니다!!
